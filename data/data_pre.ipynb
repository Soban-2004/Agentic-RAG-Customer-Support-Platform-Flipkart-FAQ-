# %%
import pandas as pd

# %%
df = pd.read_csv('flipkart_helpcentre.csv')
df.head()
# Out:
#               Topic                                           Question  \
# 0  Delivery related  What should I do if my order is approved but h...
# 1  Delivery related  Can I take the shipment after opening and chec...
# 2  Delivery related          How quickly can I get my order delivered?
# 3  Delivery related  What are the standard shipping speeds and deli...
# 4  Delivery related  When will I get my order once its status chang...
#
#                                               Answer
# 0  Sellers usually ship orders 1-2 business days ...
# 1  As per company policy, a shipment can't be ope...
# 2  Orders will be delivered by the date you see o...
# 3  Standard Delivery charges and shipping timelin...
# 4  Once an order is out for delivery, please wait...

# %%
df.shape
# Out:
# (807, 3)

# %%
df.columns
# Out:
# Index(['Topic', 'Question', 'Answer'], dtype='object')

# %%
df.describe()
# Out:
#              Topic                                           Question  \
# count          807                                                807
# unique          42                                                795
# top     SuperCoins  The address while ordering the Hero MotoCorp 2...
# freq            63                                                  2
#
#                                                    Answer
# count                                                 807
# unique                                                798
# top     You can contact the brand authorised dealer fo...
# freq                                                    2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 807 entries, 0 to 806
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Topic     807 non-null    object
#  1   Question  807 non-null    object
#  2   Answer    807 non-null    object
# dtypes: object(3)
# memory usage: 19.0+ KB

# %%
topic_counts = df.groupby("Topic", sort=False)["Question"].count().reset_index()
# Rename column
topic_counts.columns = ["Topic", "Count"]
topic_counts
# Out:
#                                       Topic  Count
# 0                          Delivery related     35
# 1                         Open box delivery     12
# 2                      Login and my account     14
# 3                           Refunds related     21
# 4                              Flipkart EMI     60
# 5                                   Payment     33
# 6                         Bajaj Finserv EMI     16
# 7                   EMI / Pre-approved loan     11
# 8                   Credit Card No Cost EMI     15
# 9            Flipkart Axis Bank Credit Card     19
# 10                 Returns & Pickup related      2
# 11                           Return related     21
# 12                           Pickup related     10
# 13                     Cancellation related      6
# 14                                  Grocery     26
# 15                               SuperCoins     63
# 16                            Flipkart Plus     17
# ...

# %%
new_df = pd.DataFrame({
    'Question': df['Question'],
    'Answer': df['Answer']
})

new_df
# Out:
#                                               Question  \
# 0    What should I do if my order is approved but h...
# 1    Can I take the shipment after opening and chec...
# 2            How quickly can I get my order delivered?
# 3    What are the standard shipping speeds and deli...
# 4    When will I get my order once its status chang...
# 5    Why am I unable to order products like televis...
# 6    Are faster delivery options like Same Day & In...
# 7    What should I do if I find the package open or...
# 8    Why did the delivery executive refuse to picku...
# 9     Can my order be prioritised or delivered faster?
# 10   The delivery of my order is delayed. What shou...
# 11   My order status is delivered but I have not go...
# 12                    How do I track my order details?
# 13       Can I collect the product from warehouse/hub?
# 14   How can I modify/add an alternate number for t...
# 15   How can I check which address I provided, and ...
# ...

# %%
new_df.to_csv('faq_data.csv', index=False)
